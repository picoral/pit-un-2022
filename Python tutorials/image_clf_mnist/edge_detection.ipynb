# %%
import imutils, cv2

# %%
img_path = "data/kagglecatsanddogs_5340/PetImages/Cat/0.jpg"
image = cv2.imread(img_path)
image
# Out:
# array([[[ 87, 164, 203],
#         [ 87, 164, 203],
#         [ 88, 165, 204],
#         ...,
#         [122, 201, 240],
#         [121, 200, 239],
#         [120, 199, 238]],
#
#        [[ 87, 164, 203],
#         [ 87, 164, 203],
#         [ 88, 165, 204],
#         ...,
#         [122, 201, 240],
#         [121, 200, 239],
#         [121, 200, 239]],
#
#        [[ 87, 164, 203],
#         [ 87, 164, 203],
#         [ 88, 165, 204],
#         ...,
#         [123, 202, 241],
#         [122, 201, 240],
#         [121, 200, 239]],
#
#        ...,
#
#        [[ 55, 122, 153],
#         [ 55, 122, 153],
#         [ 55, 122, 153],
#         ...,
#         [  0,   2,   2],
#         [  0,   2,   2],
#         [  0,   2,   2]],
#
#        [[ 54, 121, 152],
#         [ 54, 121, 152],
#         [ 54, 121, 152],
#         ...,
#         [  0,   1,   1],
#         [  0,   1,   1],
#         [  0,   1,   1]],
#
#        [[ 53, 120, 151],
#         [ 53, 120, 151],
#         [ 54, 121, 152],
#         ...,
#         [  0,   1,   1],
#         [  0,   1,   1],
#         [  0,   1,   1]]], dtype=uint8)

# %%
cv2.imshow("Image", image)
cv2.waitKey(0)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[167, 167, 168, ..., 204, 203, 202],
#        [167, 167, 168, ..., 204, 203, 203],
#        [167, 167, 168, ..., 205, 204, 203],
#        ...,
#        [124, 124, 124, ...,   2,   2,   2],
#        [123, 123, 123, ...,   1,   1,   1],
#        [122, 122, 123, ...,   1,   1,   1]], dtype=uint8)

# %%
gray = cv2.GaussianBlur(gray, (7, 7), 0)

# %%
gray
# Out:
# array([[167, 168, 168, ..., 204, 204, 203],
#        [167, 168, 168, ..., 204, 204, 204],
#        [167, 168, 168, ..., 205, 204, 204],
#        ...,
#        [124, 124, 124, ...,   2,   2,   2],
#        [123, 123, 124, ...,   1,   1,   1],
#        [123, 123, 123, ...,   1,   1,   1]], dtype=uint8)

# %%
# image of pool
image = cv2.imread('data/IMG_0398.JPG')
image
# Out:
# array([[[ 72,  73,  53],
#         [ 71,  72,  52],
#         [ 69,  70,  50],
#         ...,
#         [122, 135, 109],
#         [123, 136, 110],
#         [126, 139, 113]],
#
#        [[ 75,  76,  56],
#         [ 72,  73,  53],
#         [ 70,  71,  51],
#         ...,
#         [123, 136, 110],
#         [126, 139, 113],
#         [131, 144, 118]],
#
#        [[ 76,  77,  57],
#         [ 73,  74,  54],
#         [ 69,  71,  51],
#         ...,
#         [127, 140, 114],
#         [129, 142, 116],
#         [131, 144, 118]],
#
#        ...,
#
#        [[  4,   3,   0],
#         [  4,   3,   0],
#         [  4,   3,   0],
#         ...,
#         [  4,   3,   0],
#         [  5,   4,   0],
#         [  5,   4,   0]],
#
#        [[  4,   3,   0],
#         [  4,   3,   0],
#         [  4,   3,   0],
#         ...,
#         [  4,   3,   0],
#         [  4,   3,   0],
#         [  4,   3,   0]],
#
#        [[  4,   3,   0],
#         [  4,   3,   0],
#         [  4,   3,   0],
#         ...,
#         [  3,   2,   0],
#         [  3,   2,   0],
#         [  3,   2,   0]]], dtype=uint8)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[ 67,  66,  64, ..., 126, 127, 130],
#        [ 70,  67,  65, ..., 127, 130, 135],
#        [ 71,  68,  65, ..., 131, 133, 135],
#        ...,
#        [  2,   2,   2, ...,   2,   3,   3],
#        [  2,   2,   2, ...,   2,   2,   2],
#        [  2,   2,   2, ...,   2,   2,   2]], dtype=uint8)
